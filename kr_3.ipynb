# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
submission=pd.read_csv('sample_submission.csv')

# %%
train
# Out:
#        Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0       1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1       2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2       3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3       4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4       5          60       RL    14260   Pave      IR1         Lvl    AllPub
# ..    ...         ...      ...      ...    ...      ...         ...       ...
# 995   996          50       RL     4712   Pave      IR1         Lvl    AllPub
# 996   997          20       RL    10659   Pave      IR1         Lvl    AllPub
# 997   998          20       RL    11717   Pave      IR1         Lvl    AllPub
# 998   999          30       RM     9786   Pave      Reg         Lvl    AllPub
# 999  1000          20       RL     6762   Pave      Reg         Lvl    AllPub
#
# ...

# %%
test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1001          20       RL         74.0    10206   Pave   NaN      Reg
# 1    1002          30       RL         60.0     5400   Pave   NaN      Reg
# 2    1003          20       RL         75.0    11957   Pave   NaN      IR1
# 3    1004          90       RL          NaN    11500   Pave   NaN      IR1
# 4    1005         120       RL         43.0     3182   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
submission
# Out:
#        Id  SalePrice
# 0    1001        0.0
# 1    1002        0.0
# 2    1003        0.0
# 3    1004        0.0
# 4    1005        0.0
# ..    ...        ...
# 455  1456        0.0
# 456  1457        0.0
# 457  1458        0.0
# 458  1459        0.0
# 459  1460        0.0
#
# [460 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
cmap = sns.cubehelix_palette(as_cmap=True, light=.8)

sns.heatmap(train.isna().transpose(), cmap=cmap, cbar_kws={'label':'Missing Data'}, linewidth=0.05)
# Out:
# <Axes: >

# %%
print(train.isna().sum())
print('-----------')
print(test.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      173
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
# -----------
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      86
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
train = train.drop(columns=['PoolQC','Fence','MiscFeature','GarageCond','GarageQual','GarageFinish','GarageYrBlt','GarageType','FireplaceQu','BsmtFinType2','BsmtFinType1','BsmtExposure','BsmtCond','BsmtQual','MasVnrArea','MasVnrType','LotFrontage'])
test = test.drop(columns=['PoolQC','Fence','MiscFeature','GarageCond','GarageQual','GarageFinish','GarageYrBlt','GarageType','FireplaceQu','BsmtFinType2','BsmtFinType1','BsmtExposure','BsmtCond','BsmtQual','MasVnrArea','MasVnrType','LotFrontage'])
train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-0176530d45f3> in <cell line: 1>()
# ----> 1 train = train.drop(columns=['PoolQC','Fence','MiscFeature','GarageCond','GarageQual','GarageFinish','GarageYrBlt','GarageType','FireplaceQu','BsmtFinType2','BsmtFinType1','BsmtExposure','BsmtCond','BsmtQual','MasVnrArea','MasVnrType','LotFrontage'])
#       2 test = test.drop(columns=['PoolQC','Fence','MiscFeature','GarageCond','GarageQual','GarageFinish','GarageYrBlt','GarageType','FireplaceQu','BsmtFinType2','BsmtFinType1','BsmtExposure','BsmtCond','BsmtQual','MasVnrArea','MasVnrType','LotFrontage'])
#       3 train
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
# ...

# %%
import missingno as msno
msno.bar(train)
# Out:
# <Axes: >

# %%
train.SalePrice
# Out:
# 0      208500
# 1      181500
# 2      223500
# 3      140000
# 4      250000
#         ...
# 995    121600
# 996    136500
# 997    185000
# 998     91000
# 999    206000
# Name: SalePrice, Length: 1000, dtype: int64

# %%
train
# Out:
#        Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0       1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1       2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2       3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3       4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4       5          60       RL    14260   Pave      IR1         Lvl    AllPub
# ..    ...         ...      ...      ...    ...      ...         ...       ...
# 995   996          50       RL     4712   Pave      IR1         Lvl    AllPub
# 996   997          20       RL    10659   Pave      IR1         Lvl    AllPub
# 997   998          20       RL    11717   Pave      IR1         Lvl    AllPub
# 998   999          30       RM     9786   Pave      Reg         Lvl    AllPub
# 999  1000          20       RL     6762   Pave      Reg         Lvl    AllPub
#
# ...

# %%
train=train.drop(columns=['Street','Neighborhood'])
test=test.drop(columns=['Street','Neighborhood'])

# %%
categ = ['MSZoning','LotShape','LandContour','Utilities','LotConfig','LandSlope','Condition1','Condition2','BldgType','HouseStyle','RoofStyle']

for i in categ:
    print(i)
    print(set(test[i].unique()).difference(set(train[i].unique())))
    print('-'*15)
# Out:
# MSZoning
# set()
# ---------------
# LotShape
# set()
# ---------------
# LandContour
# set()
# ---------------
# Utilities
# set()
# ---------------
# LotConfig
# set()
# ---------------
# LandSlope
# set()
# ---------------
# Condition1
# set()
# ---------------
# Condition2
# {'RRAn', 'RRAe'}
# ---------------
# BldgType
# set()
# ---------------
# HouseStyle
# set()
# ---------------
# RoofStyle
# {'Shed'}
# ---------------

# %%
category = train.loc[:, train.dtypes == object].columns
category
# Out:
# Index(['MSZoning', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual',
#        'ExterCond', 'Foundation', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'PavedDrive', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
from sklearn import preprocessing
# Encode Categorical Columns
# создание и обучение
arr = ['MSZoning', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual',
       'ExterCond', 'Foundation', 'Heating', 'HeatingQC', 'CentralAir',
       'Electrical', 'KitchenQual', 'Functional', 'PavedDrive', 'SaleType',
       'SaleCondition']

le = preprocessing.LabelEncoder()
train['SalePrize'] = le.fit_transform(train['SalePrice'])

for i in arr:
    train[i] = le.fit_transform(train[i])
    test[i] = le.fit_transform(test[i])

train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotArea  LotShape  LandContour  Utilities  \
# 0   1          60         3     8450         3            3          0
# 1   2          20         3     9600         3            3          0
# 2   3          60         3    11250         0            3          0
# 3   4          70         3     9550         0            3          0
# 4   5          60         3    14260         0            3          0
#
#    LotConfig  LandSlope  Condition1  ...  EnclosedPorch  3SsnPorch  \
# 0          4          0           2  ...              0          0
# 1          2          0           1  ...              0          0
# 2          4          0           2  ...              0          0
# 3          0          0           2  ...            272          0
# 4          2          0           2  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
X = train.drop(columns=['SalePrice'])
y = train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Train dataset size: {X_test.shape}, {y_test.shape}')
# Out:
# Train dataset size: (700, 60), (700,)
# Train dataset size: (300, 60), (300,)

# %%
from sklearn.tree import DecisionTreeClassifier

# Создадим модель дерева решений
model = DecisionTreeClassifier()

# обучение модели
model.fit(X_train, y_train)

# предсказание ответов для тестовой выборки
answers_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# answers_pred - ответы которые вернула модель для X_test
# y_test - это правильные ответы для X_test
print(f'Accuracy: {accuracy_score(y_test, answers_pred)}')
# Out:
# Accuracy: 0.006666666666666667

# %%
y_pred_test = model.predict(test)

y_pred_test = pd.DataFrame(data = y_pred_test, columns=['Onshore/Offshore'])

y_pred_test = y_pred_test.reset_index()

y_pred_test.to_csv('solution.csv', index = False)

# %%
for i in range(460):
  y_pred_test['index']=y_pred_test['index'].replace(i+1001)
